# %%
# RL4RS Tutorial v1.0 2022.07.13

# %%
# Step 1: Installing
# !git clone https://github.com/fuxiAIlab/RL4RS
# !export PYTHONPATH=$PYTHONPATH:`pwd`/rl4rs
# !conda env create -f environment.yml
# !conda activate rl4rs

# %%
# Step 2: Dataset Introduction

# %% [markdown]
# ![](https://i.bmp.ovh/imgs/2022/07/14/c5e51bb495e704ec.png)

# %%
! head -2 /project/wangkai/rl4rs_benchmark_materials/raw_data/rl4rs_dataset_a_sl.csv
# Out:
# timestamp@session_id@sequence_id@exposed_items@user_feedback@user_seqfeature@user_protrait@item_feature@behavior_policy_id
# 2992008@1@1@3,5,29,72,53,52,164,211,172@1,1,1,1,1,1,1,1,1@24,7,1,127,74,47,212,199,6,15,10,127,126,76,220,196,172,196,15,39,31,132,80,61,200,219,1,5,14,101,40,52,235,238,164,1,14,20,77,80,40,239,233,164,164,33,31,14,139,83,83,125,184,240,160,8,1,25,51,76,43,235,211,164,14,4,9,126,116,43,164,213,183,6,14,4,43,126,57,183,188,164,10,39,25,102,109,111,160,160,157,183,10,5,32,43,103,50,242,172,171,171,35,9,5,86,48,88,218,236,215@64054,50887,66367,44932,59460,20543,83978,50138,74820,58670,3.146,13.82,1.268,4.848,7.523,9.176,9.875,10.66,9.355,9.774,10.29,17.51,7.418,6.973,0,2.683,0,17.45,2.368,17.24,12.07,0,0,0,0,12.02,10.32,11.78,1.009,30.16,0,0@-0.2137,2.0783,-0.3633,-0.142,1.372,-0.6294,-1.8973,-1.7015,-0.8995,0.4999,-1.0659,-1.1485,1.4111,1.5868,0.2704,1.5112,-0.4576,1.2751,1.0225,1.1452,-1.4702,-1.388,0.6215,1.5247,1.6815,0.6815,1.3391,-0.7501,1.0955,-1.1044,0.6773,-1.3632,0.1231,0.805,-0.3372,0.5489,-0.445,-1.5474,-0.8624,1.201;-0.2137,-0.7579,-0.3633,-0.1352,1.3293,-0.7099,-1.8973,-1.677,1.6924,1.1324,-0.1024,1.1928,1.7338,-0.2146,0.6337,-1.0009,-1.2873,-0.6144,-1.6587,0.4634,1.0691,1.2389,0.7369,0.9045,-1.1352,-1.3375,1.7778,-1.1019,-1.6901,1.1034,-0.5661,-0.8314,0.0778,-0.7026,-1.7152,-0.5689,0.1662,-0.505,0.3174,1.4195;1.5653,-0.0489,-0.3633,-0.1337,1.7984,-0.4087,-1.8973,-1.3832,0.3859,1.6068,0.6345,1.5253,0.0213,1.329,-0.658,0.3951,1.7631,-1.2467,0.4961,1.1013,1.2305,1.6542,-0.4394,-0.5117,1.6133,0.994,1.2942,0.664,-1.4112,-0.222,0.8467,1.3883,-1.7096,-0.5375,0.3698,1.1702,1.3394,0.3454,-1.5845,-1.6395;-0.2137,-0.4034,-0.3633,-0.1419,1.2634,-0.5603,-0.4843,-0.8568,-0.624,0.3182,-1.0695,1.4773,-0.6808,-1.5554,1.2291,1.5043,-0.496,-0.7835,0.5562,1.3106,1.4273,1.7788,0.0333,-0.2016,-0.2801,-1.0671,1.4116,0.2349,-0.833,-0.3753,-1.3522,-1.307,1.5376,1.7131,-1.2954,-1.1362,-0.5699,1.176,-1.4218,0.2777;-1.1033,-0.7579,-0.3633,-0.1447,0.4765,-0.8246,-0.4843,-1.0894,0.0892,-1.1184,1.0839,0.4249,0.0177,1.494,-0.5806,1.1035,0.8532,1.7787,0.4697,0.7334,1.0433,0.6194,0.2678,0.9217,-0.0502,-0.702,0.8589,1.5998,-0.4045,0.0029,0.1793,0.1596,1.3495,-1.6538,0.6604,1.5552,-1.3554,0.448,-0.4895,-0.2792;-1.1033,-0.7579,-0.3633,-0.1454,0.3486,-0.8251,-0.4843,-1.1017,0.4282,-1.3875,1.4182,1.1448,-1.6062,1.0677,-0.8564,0.4228,-0.3461,-1.1989,-0.7449,-1.1872,1.1756,0.8443,-1.4354,-1.3835,-1.3041,-0.6809,1.3356,0.7098,-1.5541,0.6127,-1.3251,1.5667,-0.194,0.3096,0.5743,0.3632,0.4685,0.2031,-0.2352,-0.3144;-1.1033,1.3692,-0.3633,-0.1264,0.2788,0.8519,0.9287,0.2693,0.227,1.6404,-0.3505,-0.7714,-1.6984,-0.9709,-0.1736,-1.3879,-1.2559,-1.6143,-0.9292,-0.7957,1.5112,-1.4711,1.289,1.4627,-1.3436,1.5944,0.0644,1.4098,-1.2242,-1.0362,-1.2132,0.4403,-1.3786,1.7095,0.804,1.1128,1.2277,0.4315,1.5446,0.8169;0.6758,-0.4034,-0.3633,-0.144,0.0152,-0.418,0.9287,0.8446,-0.4404,-0.9199,0.7064,-1.5187,-1.3828,0.9783,0.1897,-1.3084,-1.1409,-1.5812,1.5904,1.2566,-0.1473,-1.6164,-1.5003,-0.8046,1.0959,1.0115,1.4151,-1.2673,-1.0915,-0.4673,1.0534,-0.5935,0.5272,0.7296,0.6712,1.2884,-0.4253,-0.2436,0.7581,-1.6677;-1.1033,1.3692,-0.3633,-0.1342,-0.5042,2.4328,0.9287,0.3672,1.3816,0.5907,0.5051,-1.0662,1.5671,0.4592,-0.7992,-1.3222,0.1211,-0.7357,-1.6813,-1.2277,-0.1247,-0.4916,-1.6122,1.3455,-1.6382,1.6927,0.6309,-1.2884,0.82,-0.2186,0.8332,-1.3599,-1.302,-0.5375,1.4607,1.1229,1.4413,1.5996,1.1378,0.0204@1

# %%
with open('/project/wangkai/rl4rs_benchmark_materials/raw_data/rl4rs_dataset_a_sl.csv', 'r') as f:
    data = f.read().split('\n')[1:-1]
    print('number of records: ', len(data))
    print('number of users: ', len(set([x.split('@')[1] for x in data])))
    print('number of items per page: ', len(data[0].split('@')[3].split(',')))
    print('avg. lengths of user history: ', sum([len(x.split('@')[5].split(',')) for x in data])/len(data))
    print('avg. dimensions of user_protrait: ', sum([len(x.split('@')[6].split(',')) for x in data])/len(data))
    print('avg. dimensions of item_feature: ', sum([len(x.split('@')[7].split(',')) for x in data])/len(data))
    print('number of behavior_policy_id: ', len(set([x.split('@')[-1] for x in data])))
# Out:
# number of records:  937949
# number of users:  937949
# number of items per page:  9
# avg. lengths of user history:  36.35307676643399
# avg. dimensions of user_protrait:  42.0
# avg. dimensions of item_feature:  352.0
# number of behavior_policy_id:  1

# %%
# Step 2: Data PreProcess
# See https://github.com/fuxiAIlab/RL4RS/blob/main/reproductions/run_split.sh

# %%
# Step 3: Simulation Environment (Local)

# %%
import os, sys
import gym
import numpy as np
from copy import deepcopy
import tensorflow as tf
from rl4rs.utils.datautil import FeatureUtil
from rl4rs.env.slate import SlateRecEnv, SlateState
from rl4rs.env.seqslate import SeqSlateRecEnv, SeqSlateState

# %%
config = {"epoch": 10000, "maxlen": 64, "batch_size": 64, "action_size": 284, 
          "class_num": 2, "dense_feature_num": 432, "category_feature_num": 21, 
          "category_hash_size": 100000, "seq_num": 2, "emb_size": 128, "is_eval": False,
          "hidden_units": 128, "max_steps": 9, "action_emb_size": 32,
          "sample_file": '/project/wangkai/rl4rs_benchmark_materials/simulator/rl4rs_dataset_a_shuf.csv', 
          "model_file": "/project/wangkai/rl4rs_benchmark_materials/simulator/finetuned/simulator_a_dien/model",
          "iteminfo_file": '/project/wangkai/rl4rs_benchmark_materials/raw_data/item_info.csv', 
          "support_rllib_mask": True, 'env': "SlateRecEnv-v0"}

sim = SlateRecEnv(config, state_cls=SlateState)
env = gym.make('SlateRecEnv-v0', recsim=sim)
# Out:
# INFO:tensorflow:Restoring parameters from /project/wangkai/rl4rs_benchmark_materials/simulator/finetuned/simulator_a_dien/model
# INFO:tensorflow:Restoring parameters from /project/wangkai/rl4rs_benchmark_materials/simulator/finetuned/simulator_a_dien/model

# %%
obs = env.reset()
print('batchsize of batched environment: ', len(obs))

for i in range(config["max_steps"]):
    action = env.offline_action
    next_obs, reward, done, info = env.step(action)
    print('step: ', i, ' action', action[0], ' reward: ', reward[0], ' offline reward: ', env.offline_reward[0], ' done: ', done[0])
    
print('observation type: ', type(next_obs[0]))
print('size of obs.action_mask: ', len(next_obs[0]['action_mask']))
print('size of obs.obs: ', len(next_obs[0]['obs']))
# Out:
# batchsize of batched environment:  64
# step:  0  action 31  reward:  0  offline reward:  0  done:  0
# step:  1  action 28  reward:  0  offline reward:  0  done:  0
# step:  2  action 20  reward:  0  offline reward:  0  done:  0
# step:  3  action 87  reward:  0  offline reward:  0  done:  0
# step:  4  action 73  reward:  0  offline reward:  0  done:  0
# step:  5  action 146  reward:  0  offline reward:  0  done:  0
# step:  6  action 235  reward:  0  offline reward:  0  done:  0
# step:  7  action 233  reward:  0  offline reward:  0  done:  0
# step:  8  action 166  reward:  130.2745725877583  offline reward:  118.5  done:  1
# observation type:  <class 'dict'>
# size of obs.action_mask:  284
# size of obs.obs:  256

# %%
# Env with continus action space (without item mask)

# %%
config_conti = deepcopy(config)
config_conti['support_conti_env'] = True
config_conti['support_rllib_mask'] = False
sim = SlateRecEnv(config_conti, state_cls=SlateState)
env = gym.make('SlateRecEnv-v0', recsim=sim)
obs = env.reset()
action_vec = np.full((batch_size, 32), 1)
print('size of action embedding ', np.array(env.samples.action_emb).shape)
for i in range(config["max_steps"]):
    next_obs, reward, done, info = env.step(action_vec)
    action = SlateState.get_nearest_neighbor(action_vec, env.samples.action_emb)
    print('step: ', i, ' action', action[0], ' reward: ', reward[0], ' done: ', done[0])
# Out:
# INFO:tensorflow:Restoring parameters from /project/wangkai/rl4rs_benchmark_materials/simulator/finetuned/simulator_a_dien/model
# INFO:tensorflow:Restoring parameters from /project/wangkai/rl4rs_benchmark_materials/simulator/finetuned/simulator_a_dien/model
# size of action embedding  (284, 32)
# step:  0  action 53  reward:  0  done:  0
# step:  1  action 53  reward:  0  done:  0
# step:  2  action 53  reward:  0  done:  0
# step:  3  action 53  reward:  0  done:  0
# step:  4  action 53  reward:  0  done:  0
# step:  5  action 53  reward:  0  done:  0
# step:  6  action 53  reward:  0  done:  0
# step:  7  action 53  reward:  0  done:  0
# step:  8  action 53  reward:  47.939698447287086  done:  1

# %%
# Env with continus action space (with item mask)
# See https://github.com/fuxiAIlab/RL4RS/blob/main/script/modelfree_train.py

# %%
# Take raw features as observation

# %%
from copy import deepcopy
config_rawstate = deepcopy(config)
config_rawstate['support_rllib_mask'] = True
config_rawstate['support_conti_env'] = False
config_rawstate['rawstate_as_obs'] = True
sim = SlateRecEnv(config_rawstate, state_cls=SlateState)
env = gym.make('SlateRecEnv-v0', recsim=sim)
obs = env.reset()
print('observation type: ', type(obs[0]))
print('size of obs.action_mask: ', len(obs[0]['action_mask']))
print('size of obs.category_feature: ', len(obs[0]['category_feature']))
print('size of obs.dense_feature: ', len(obs[0]['dense_feature']))
print('size of obs.sequence_feature: ', obs[0]['sequence_feature'].shape)
# Out:
# INFO:tensorflow:Restoring parameters from /project/wangkai/rl4rs_benchmark_materials/simulator/finetuned/simulator_a_dien/model
# INFO:tensorflow:Restoring parameters from /project/wangkai/rl4rs_benchmark_materials/simulator/finetuned/simulator_a_dien/model
# observation type:  <class 'dict'>
# size of obs.action_mask:  284
# size of obs.category_feature:  21
# size of obs.dense_feature:  432
# size of obs.sequence_feature:  (2,64)

# %%
# Step 3: Simulation Environment (Remote)
# start http-based Env, then run RLlib library
# nohup python -u rl4rs/server/gymHttpServer.py &
# bash run_modelfree_rl.sh DQN/PPO/DDPG/PG/PG_conti/etc.

# %%
# Step 4: Model-free Training (RLLib)

# %%
import os
import numpy as np
import gym
import ray
from ray.rllib.models import ModelCatalog
from ray.tune.registry import register_env
from rl4rs.utils.rllib_print import pretty_print
from rl4rs.nets.rllib.rllib_rawstate_model import getTFModelWithRawState
from rl4rs.nets.rllib.rllib_mask_model import getMaskActionsModel, \
    getMaskActionsModelWithRawState
from rl4rs.utils.rllib_vector_env import MyVectorEnvWrapper
from script.modelfree_trainer import get_rl_model
from rl4rs.policy.behavior_model import behavior_model
from script.offline_evaluation import ope_eval
from rl4rs.utils.fileutil import find_newest_files
import http.client
import sys
http.client.HTTPConnection._http_vsn = 10
http.client.HTTPConnection._http_vsn_str = 'HTTP/1.0'

algo = 'PPO'

ray.init()

config = {"epoch": 2, "maxlen": 64, "batch_size": 64, "action_size": 284, 
          "class_num": 2, "dense_feature_num": 432, "category_feature_num": 21, 
          "category_hash_size": 100000, "seq_num": 2, "emb_size": 128, "is_eval": False,
          "hidden_units": 128, "max_steps": 9, "action_emb_size": 32,
          "sample_file": '/project/wangkai/rl4rs_benchmark_materials/simulator/rl4rs_dataset_a_shuf.csv', 
          "model_file": "/project/wangkai/rl4rs_benchmark_materials/simulator/finetuned/simulator_a_dien/model",
          "iteminfo_file": '/project/wangkai/rl4rs_benchmark_materials/raw_data/item_info.csv', 
          'remote_base': 'http://127.0.0.1:5000', 'trial_name': 'all',
          "support_rllib_mask": True, 'env': "SlateRecEnv-v0"}

print(config)

mask_model = getMaskActionsModel(true_obs_shape=(256,), action_size=config['action_size'])
ModelCatalog.register_custom_model("mask_model", mask_model)
mask_model_rawstate = getMaskActionsModelWithRawState(config=config, action_size=config['action_size'])
ModelCatalog.register_custom_model("mask_model_rawstate", mask_model_rawstate)
model_rawstate = getTFModelWithRawState(config=config)
ModelCatalog.register_custom_model("model_rawstate", model_rawstate)
register_env('rllibEnv-v0', lambda _: MyVectorEnvWrapper(gym.make('HttpEnv-v0', env_id=config['env'], config=config), config['batch_size']))

cfg = {
    "num_workers": 2,
    "use_critic": True,
    "use_gae": True,
    "lambda": 1.0,
    "kl_coeff": 0.2,
    "sgd_minibatch_size": 256,
    "shuffle_sequences": True,
    "num_sgd_iter": 1,
    "lr": 0.0001,
    "vf_loss_coeff": 0.5,
    "clip_param": 0.3,
    "vf_clip_param": 500.0,
    "kl_target": 0.01,
}

rllib_config = dict(
    {
        "env": "rllibEnv-v0",
        "gamma": 1,
        "explore": True,
        "exploration_config": {
            "type": "SoftQ",
            # "temperature": 1.0,
        },
        "num_gpus": 1 if config.get('gpu', True) else 0,
        "num_workers": 0,
        "framework": 'tf',
        "rollout_fragment_length": config['max_steps'],
        "batch_mode": "complete_episodes",
        "train_batch_size": min(config["batch_size"] * config['max_steps'], 1024),
        "evaluation_interval": 1,
        "evaluation_num_episodes": 2048 * 4,
        "evaluation_config": {
            "explore": False
        },
        "log_level": "INFO",
    },
    **cfg)
print('rllib_config', rllib_config)
trainer = get_rl_model(algo, rllib_config)

# restore_file = ''
# trainer.restore(restore_file)

for i in range(config["epoch"]):
    result = trainer.train()
    if (i + 1) % 1 == 0 or i == 0:
        print(pretty_print(result))


ray.shutdown()
# Out:
# /project/miniconda3/envs/rl4rs/lib/python3.6/site-packages/ray/autoscaler/_private/cli_logger.py:61: FutureWarning: Not all Ray CLI dependencies were found. In Ray 1.4+, the Ray CLI, autoscaler, and dashboard will only be usable via `pip install 'ray[default]'`. Please update your install command.
#   "update your install command.", FutureWarning)
# 2022-07-14 17:34:22,072	WARNING utils.py:511 -- Detecting docker specified CPUs. In previous versions of Ray, CPU detection in containers was incorrect. Please ensure that Ray has enough CPUs allocated. As a temporary workaround to revert to the prior behavior, set `RAY_USE_MULTIPROCESSING_CPU_COUNT=1` as an env var before starting Ray. Set the env var: `RAY_DISABLE_DOCKER_CPU_WARNING=1` to mute this warning.
# 2022-07-14 17:34:45,283	ERROR services.py:1254 -- Failed to start the dashboard: Failed to start the dashboard. The last 10 lines of /tmp/ray/session_2022-07-14_17-34-22_052438_47614/logs/dashboard.log:
# 2022-07-14 17:34:41,447	INFO dashboard.py:92 -- Setup static dir for dashboard: /project/miniconda3/envs/rl4rs/lib/python3.6/site-packages/ray/new_dashboard/client/build
# 2022-07-14 17:34:41,451	INFO head.py:82 -- Connect to GCS at b'192.168.98.96:43889'
# 2022-07-14 17:34:41,453	INFO utils.py:202 -- Get all modules by type: DashboardHeadModule
# {'epoch': 2, 'maxlen': 64, 'batch_size': 64, 'action_size': 284, 'class_num': 2, 'dense_feature_num': 432, 'category_feature_num': 21, 'category_hash_size': 100000, 'seq_num': 2, 'emb_size': 128, 'is_eval': False, 'hidden_units': 128, 'max_steps': 9, 'action_emb_size': 32, 'sample_file': '/project/wangkai/rl4rs_benchmark_materials/simulator/rl4rs_dataset_a_shuf.csv', 'model_file': '/project/wangkai/rl4rs_benchmark_materials/simulator/finetuned/simulator_a_dien/model', 'iteminfo_file': '/project/wangkai/rl4rs_benchmark_materials/raw_data/item_info.csv', 'remote_base': 'http://127.0.0.1:5000', 'trial_name': 'all', 'support_rllib_mask': True, 'env': 'SlateRecEnv-v0'}
# rllib_config {'env': 'rllibEnv-v0', 'gamma': 1, 'explore': True, 'exploration_config': {'type': 'SoftQ'}, 'num_gpus': 1, 'num_workers': 2, 'framework': 'tf', 'rollout_fragment_length': 9, 'batch_mode': 'complete_episodes', 'train_batch_size': 576, 'evaluation_interval': 1, 'evaluation_num_episodes': 8192, 'evaluation_config': {'explore': False}, 'log_level': 'INFO', 'use_critic': True, 'use_gae': True, 'lambda': 1.0, 'kl_coeff': 0.2, 'sgd_minibatch_size': 256, 'shuffle_sequences': True, 'num_sgd_iter': 1, 'lr': 0.0001, 'vf_loss_coeff': 0.5, 'clip_param': 0.3, 'vf_clip_param': 500.0, 'kl_target': 0.01}
# 2022-07-14 17:34:48,364	INFO trainer.py:706 -- Tip: set framework=tfe or the --eager flag to enable TensorFlow eager execution
# (pid=47823) /project/miniconda3/envs/rl4rs/lib/python3.6/site-packages/gym/logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
# (pid=47823)   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))
# (pid=47832) /project/miniconda3/envs/rl4rs/lib/python3.6/site-packages/gym/logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
# (pid=47832)   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))
# (pid=47823) WARNING:tensorflow:From /project/miniconda3/envs/rl4rs/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (pid=47823) Instructions for updating:
# (pid=47823) If using Keras pass *_constraint arguments to layers.
# (pid=47832) WARNING:tensorflow:From /project/miniconda3/envs/rl4rs/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# (pid=47832) Instructions for updating:
# (pid=47832) If using Keras pass *_constraint arguments to layers.
# (pid=47823) 2022-07-14 17:35:04,153	INFO dynamic_tf_policy.py:472 -- Testing `compute_actions` w/ dummy batch.
# (pid=47832) 2022-07-14 17:35:04,217	INFO dynamic_tf_policy.py:472 -- Testing `compute_actions` w/ dummy batch.
# (pid=47832) 2022-07-14 17:35:04,217	INFO tf_run_builder.py:87 -- Executing TF run without tracing. To dump TF timeline traces to disk, set the TF_TIMELINE_DIR environment variable.
# (pid=47823) 2022-07-14 17:35:04,221	INFO dynamic_tf_policy.py:481 -- Adding extra-action-fetch `action_prob` to view-reqs.
# (pid=47823) 2022-07-14 17:35:04,222	INFO dynamic_tf_policy.py:481 -- Adding extra-action-fetch `action_logp` to view-reqs.
# (pid=47823) 2022-07-14 17:35:04,223	INFO dynamic_tf_policy.py:481 -- Adding extra-action-fetch `action_dist_inputs` to view-reqs.
# (pid=47823) 2022-07-14 17:35:04,223	INFO dynamic_tf_policy.py:481 -- Adding extra-action-fetch `vf_preds` to view-reqs.
# (pid=47823) 2022-07-14 17:35:04,223	INFO dynamic_tf_policy.py:488 -- Testing `postprocess_trajectory` w/ dummy batch.
# (pid=47832) 2022-07-14 17:35:04,283	INFO dynamic_tf_policy.py:481 -- Adding extra-action-fetch `action_prob` to view-reqs.
# (pid=47832) 2022-07-14 17:35:04,284	INFO dynamic_tf_policy.py:481 -- Adding extra-action-fetch `action_logp` to view-reqs.
# (pid=47832) 2022-07-14 17:35:04,285	INFO dynamic_tf_policy.py:481 -- Adding extra-action-fetch `action_dist_inputs` to view-reqs.
# (pid=47832) 2022-07-14 17:35:04,286	INFO dynamic_tf_policy.py:481 -- Adding extra-action-fetch `vf_preds` to view-reqs.
# (pid=47832) 2022-07-14 17:35:04,286	INFO dynamic_tf_policy.py:488 -- Testing `postprocess_trajectory` w/ dummy batch.
# (pid=47823) WARNING:tensorflow:From /project/miniconda3/envs/rl4rs/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# (pid=47823) Instructions for updating:
# (pid=47823) Use tf.where in 2.0, which has the same broadcast rule as np.where
# (pid=47832) WARNING:tensorflow:From /project/miniconda3/envs/rl4rs/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# (pid=47832) Instructions for updating:
# (pid=47832) Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /project/miniconda3/envs/rl4rs/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2022-07-14 17:35:06,254	INFO dynamic_tf_policy.py:472 -- Testing `compute_actions` w/ dummy batch.
# 2022-07-14 17:35:06,257	INFO tf_run_builder.py:87 -- Executing TF run without tracing. To dump TF timeline traces to disk, set the TF_TIMELINE_DIR environment variable.
# 2022-07-14 17:35:06,467	INFO dynamic_tf_policy.py:481 -- Adding extra-action-fetch `action_prob` to view-reqs.
# 2022-07-14 17:35:06,470	INFO dynamic_tf_policy.py:481 -- Adding extra-action-fetch `action_logp` to view-reqs.
# 2022-07-14 17:35:06,472	INFO dynamic_tf_policy.py:481 -- Adding extra-action-fetch `action_dist_inputs` to view-reqs.
# 2022-07-14 17:35:06,474	INFO dynamic_tf_policy.py:481 -- Adding extra-action-fetch `vf_preds` to view-reqs.
# 2022-07-14 17:35:06,475	INFO dynamic_tf_policy.py:488 -- Testing `postprocess_trajectory` w/ dummy batch.
# WARNING:tensorflow:From /project/miniconda3/envs/rl4rs/lib/python3.6/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 2022-07-14 17:35:07,609	INFO rollout_worker.py:1344 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f521435d748>}
# 2022-07-14 17:35:07,610	INFO rollout_worker.py:1345 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.DictFlatteningPreprocessor object at 0x7f521435d320>}
# 2022-07-14 17:35:07,611	INFO rollout_worker.py:602 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f51f44d3e80>}
# 2022-07-14 17:35:10,276	WARNING deprecation.py:34 -- DeprecationWarning: `simple_optimizer` has been deprecated. This will raise an error in the future!
# /project/miniconda3/envs/rl4rs/lib/python3.6/site-packages/gym/logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))
# 2022-07-14 17:35:13,350	INFO dynamic_tf_policy.py:472 -- Testing `compute_actions` w/ dummy batch.
# 2022-07-14 17:35:13,405	INFO dynamic_tf_policy.py:481 -- Adding extra-action-fetch `action_prob` to view-reqs.
# 2022-07-14 17:35:13,407	INFO dynamic_tf_policy.py:481 -- Adding extra-action-fetch `action_logp` to view-reqs.
# 2022-07-14 17:35:13,409	INFO dynamic_tf_policy.py:481 -- Adding extra-action-fetch `action_dist_inputs` to view-reqs.
# 2022-07-14 17:35:13,410	INFO dynamic_tf_policy.py:481 -- Adding extra-action-fetch `vf_preds` to view-reqs.
# 2022-07-14 17:35:13,411	INFO dynamic_tf_policy.py:488 -- Testing `postprocess_trajectory` w/ dummy batch.
# 2022-07-14 17:35:14,372	INFO rollout_worker.py:1344 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x7f4e44101b70>}
# 2022-07-14 17:35:14,373	INFO rollout_worker.py:1345 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.DictFlatteningPreprocessor object at 0x7f4e44101470>}
# 2022-07-14 17:35:14,374	INFO rollout_worker.py:602 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x7f4e44062fd0>}
# 2022-07-14 17:35:14,375	INFO trainable.py:109 -- Trainable.setup took 26.013 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (pid=47832) 2022-07-14 17:35:14,443	INFO rollout_worker.py:737 -- Generating sample batch of size 9
# trainer_default_config {'num_workers': 2, 'num_envs_per_worker': 1, 'create_env_on_driver': False, 'rollout_fragment_length': 200, 'batch_mode': 'truncate_episodes', 'gamma': 0.99, 'lr': 5e-05, 'train_batch_size': 4000, 'model': {'_use_default_native_models': False, 'fcnet_hiddens': [256, 256], 'fcnet_activation': 'tanh', 'conv_filters': None, 'conv_activation': 'relu', 'post_fcnet_hiddens': [], 'post_fcnet_activation': 'relu', 'free_log_std': False, 'no_final_linear': False, 'vf_share_layers': False, 'use_lstm': False, 'max_seq_len': 20, 'lstm_cell_size': 256, 'lstm_use_prev_action': False, 'lstm_use_prev_reward': False, '_time_major': False, 'use_attention': False, 'attention_num_transformer_units': 1, 'attention_dim': 64, 'attention_num_heads': 1, 'attention_head_dim': 32, 'attention_memory_inference': 50, 'attention_memory_training': 50, 'attention_position_wise_mlp_dim': 32, 'attention_init_gru_gate_bias': 2.0, 'attention_use_n_prev_actions': 0, 'attention_use_n_prev_rewards': 0, 'num_framestacks': 'auto', 'dim': 84, 'grayscale': False, 'zero_mean': True, 'custom_model': None, 'custom_model_config': {}, 'custom_action_dist': None, 'custom_preprocessor': None, 'lstm_use_prev_action_reward': -1, 'framestack': True}, 'optimizer': {}, 'horizon': None, 'soft_horizon': False, 'no_done_at_end': False, 'env': None, 'observation_space': None, 'action_space': None, 'env_config': {}, 'env_task_fn': None, 'render_env': False, 'record_env': False, 'clip_rewards': None, 'normalize_actions': True, 'clip_actions': False, 'preprocessor_pref': 'deepmind', 'log_level': 'WARN', 'callbacks': <class 'ray.rllib.agents.callbacks.DefaultCallbacks'>, 'ignore_worker_failures': False, 'log_sys_usage': True, 'fake_sampler': False, 'framework': 'tf', 'eager_tracing': False, 'explore': True, 'exploration_config': {'type': 'StochasticSampling'}, 'evaluation_interval': None, 'evaluation_num_episodes': 10, 'evaluation_parallel_to_training': False, 'in_evaluation': False, 'evaluation_config': {}, 'evaluation_num_workers': 0, 'custom_eval_function': None, 'sample_async': False, 'sample_collector': <class 'ray.rllib.evaluation.collectors.simple_list_collector.SimpleListCollector'>, 'observation_filter': 'NoFilter', 'synchronize_filters': True, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'compress_observations': False, 'collect_metrics_timeout': 180, 'metrics_smoothing_episodes': 100, 'remote_worker_envs': False, 'remote_env_batch_wait_ms': 0, 'min_iter_time_s': 0, 'timesteps_per_iteration': 0, 'seed': None, 'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'num_gpus': 0, '_fake_gpus': False, 'num_cpus_per_worker': 1, 'num_gpus_per_worker': 0, 'custom_resources_per_worker': {}, 'num_cpus_for_driver': 1, 'placement_strategy': 'PACK', 'input': 'sampler', 'input_config': {}, 'actions_in_input_normalized': False, 'input_evaluation': ['is', 'wis'], 'postprocess_inputs': False, 'shuffle_buffer_size': 0, 'output': None, 'output_compress_columns': ['obs', 'new_obs'], 'output_max_file_size': 67108864, 'multiagent': {'policies': {}, 'policy_mapping_fn': None, 'policies_to_train': None, 'observation_fn': None, 'replay_mode': 'independent', 'count_steps_by': 'env_steps'}, 'logger_config': None, 'simple_optimizer': -1, 'monitor': -1, 'use_critic': True, 'use_gae': True, 'lambda': 1.0, 'kl_coeff': 0.2, 'sgd_minibatch_size': 128, 'shuffle_sequences': True, 'num_sgd_iter': 30, 'lr_schedule': None, 'vf_loss_coeff': 1.0, 'entropy_coeff': 0.0, 'entropy_coeff_schedule': None, 'clip_param': 0.3, 'vf_clip_param': 10.0, 'grad_clip': None, 'kl_target': 0.01, 'vf_share_layers': -1}
# (pid=47832) 2022-07-14 17:35:14,667	INFO sampler.py:593 -- Raw obs from env: { 0: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                    'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=14.742, mean=0.205)}},
# (pid=47832)   1: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                    'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=6.099, mean=-0.391)}},
# (pid=47832)   2: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                    'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=10.2, mean=0.211)}},
# (pid=47832)   3: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                    'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=14.113, mean=0.086)}},
# (pid=47832)   4: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                    'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=15.212, mean=0.354)}},
# (pid=47832)   5: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                    'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=13.614, mean=-0.035)}},
# (pid=47832)   6: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                    'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=13.649, mean=-0.024)}},
# (pid=47832)   7: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                    'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=16.506, mean=0.407)}},
# (pid=47832)   8: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                    'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=14.946, mean=0.133)}},
# (pid=47832)   9: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                    'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=12.712, mean=-0.026)}},
# (pid=47832)   10: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=10.496, mean=0.132)}},
# (pid=47832)   11: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=14.514, mean=0.25)}},
# (pid=47832)   12: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=17.503, mean=0.427)}},
# (pid=47832)   13: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=17.247, mean=0.239)}},
# (pid=47832)   14: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=16.555, mean=0.016)}},
# (pid=47832)   15: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=16.864, mean=0.017)}},
# (pid=47832)   16: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=6.092, mean=-0.508)}},
# (pid=47832)   17: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=17.553, mean=0.969)}},
# (pid=47832)   18: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=15.832, mean=-0.221)}},
# (pid=47832)   19: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=30.285, mean=-0.458)}},
# (pid=47832)   20: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=12.957, mean=-0.086)}},
# (pid=47832)   21: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=26.091, mean=-0.39)}},
# (pid=47832)   22: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=14.433, mean=-0.104)}},
# (pid=47832)   23: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=11.563, mean=-0.535)}},
# (pid=47832)   24: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=15.642, mean=-0.082)}},
# (pid=47832)   25: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=10.864, mean=-0.425)}},
# (pid=47832)   26: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=11.947, mean=0.192)}},
# (pid=47832)   27: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=13.466, mean=0.138)}},
# (pid=47832)   28: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=16.986, mean=-0.656)}},
# (pid=47832)   29: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=10.284, mean=0.065)}},
# (pid=47832)   30: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=16.697, mean=0.381)}},
# (pid=47832)   31: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=10.375, mean=-0.326)}},
# (pid=47832)   32: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=15.191, mean=0.233)}},
# (pid=47832)   33: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=20.617, mean=0.53)}},
# (pid=47832)   34: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=18.512, mean=0.525)}},
# (pid=47832)   35: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=9.414, mean=-0.446)}},
# (pid=47832)   36: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=11.822, mean=0.334)}},
# (pid=47832)   37: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=20.875, mean=0.224)}},
# (pid=47832)   38: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=23.327, mean=0.888)}},
# (pid=47832)   39: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=10.214, mean=-0.268)}},
# (pid=47832)   40: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=13.178, mean=-0.127)}},
# (pid=47832)   41: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=12.537, mean=-0.388)}},
# (pid=47832)   42: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=13.01, mean=-0.274)}},
# (pid=47832)   43: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=15.221, mean=0.13)}},
# (pid=47832)   44: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=15.895, mean=-0.301)}},
# (pid=47832)   45: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=21.116, mean=-0.148)}},
# (pid=47832)   46: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=18.923, mean=-0.063)}},
# (pid=47832)   47: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=15.774, mean=-0.557)}},
# (pid=47832)   48: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=16.196, mean=0.574)}},
# (pid=47832)   49: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=17.276, mean=0.222)}},
# (pid=47832)   50: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=10.08, mean=-0.646)}},
# (pid=47832)   51: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=14.076, mean=0.27)}},
# (pid=47832)   52: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=12.056, mean=-0.504)}},
# (pid=47832)   53: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=11.149, mean=-0.133)}},
# (pid=47832)   54: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=16.62, mean=0.564)}},
# (pid=47832)   55: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=9.953, mean=-0.382)}},
# (pid=47832)   56: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=20.508, mean=0.106)}},
# (pid=47832)   57: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=15.243, mean=0.04)}},
# (pid=47832)   58: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=14.563, mean=0.216)}},
# (pid=47832)   59: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=10.52, mean=0.115)}},
# (pid=47832)   60: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=9.542, mean=0.12)}},
# (pid=47832)   61: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=12.736, mean=-0.524)}},
# (pid=47832)   62: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=17.577, mean=0.376)}},
# (pid=47832)   63: { 'agent0': { 'action_mask': np.ndarray((284,), dtype=int64, min=0.0, max=1.0, mean=0.137),
# (pid=47832)                     'obs': np.ndarray((256,), dtype=float64, min=-1.0, max=13.834, mean=0.505)}}}
# (pid=47832) 2022-07-14 17:35:14,669	INFO sampler.py:594 -- Info return from env: { 0: {'agent0': None},
# (pid=47832)   1: {'agent0': None},
# (pid=47832)   2: {'agent0': None},
# (pid=47832)   3: {'agent0': None},
# (pid=47832)   4: {'agent0': None},
# (pid=47832)   5: {'agent0': None},
# (pid=47832)   6: {'agent0': None},
# (pid=47832)   7: {'agent0': None},
# (pid=47832)   8: {'agent0': None},
# (pid=47832)   9: {'agent0': None},
# (pid=47832)   10: {'agent0': None},
# (pid=47832)   11: {'agent0': None},
# (pid=47832)   12: {'agent0': None},
# (pid=47832)   13: {'agent0': None},
# (pid=47832)   14: {'agent0': None},
# (pid=47832)   15: {'agent0': None},
# (pid=47832)   16: {'agent0': None},
# (pid=47832)   17: {'agent0': None},
# (pid=47832)   18: {'agent0': None},
# (pid=47832)   19: {'agent0': None},
# (pid=47832)   20: {'agent0': None},
# (pid=47832)   21: {'agent0': None},
# (pid=47832)   22: {'agent0': None},
# (pid=47832)   23: {'agent0': None},
# (pid=47832)   24: {'agent0': None},
# (pid=47832)   25: {'agent0': None},
# (pid=47832)   26: {'agent0': None},
# (pid=47832)   27: {'agent0': None},
# (pid=47832)   28: {'agent0': None},
# (pid=47832)   29: {'agent0': None},
# (pid=47832)   30: {'agent0': None},
# (pid=47832)   31: {'agent0': None},
# (pid=47832)   32: {'agent0': None},
# (pid=47832)   33: {'agent0': None},
# (pid=47832)   34: {'agent0': None},
# (pid=47832)   35: {'agent0': None},
# (pid=47832)   36: {'agent0': None},
# (pid=47832)   37: {'agent0': None},
# (pid=47832)   38: {'agent0': None},
# (pid=47832)   39: {'agent0': None},
# (pid=47832)   40: {'agent0': None},
# (pid=47832)   41: {'agent0': None},
# (pid=47832)   42: {'agent0': None},
# (pid=47832)   43: {'agent0': None},
# (pid=47832)   44: {'agent0': None},
# (pid=47832)   45: {'agent0': None},
# (pid=47832)   46: {'agent0': None},
# (pid=47832)   47: {'agent0': None},
# (pid=47832)   48: {'agent0': None},
# (pid=47832)   49: {'agent0': None},
# (pid=47832)   50: {'agent0': None},
# (pid=47832)   51: {'agent0': None},
# (pid=47832)   52: {'agent0': None},
# (pid=47832)   53: {'agent0': None},
# (pid=47832)   54: {'agent0': None},
# (pid=47832)   55: {'agent0': None},
# (pid=47832)   56: {'agent0': None},
# (pid=47832)   57: {'agent0': None},
# (pid=47832)   58: {'agent0': None},
# (pid=47832)   59: {'agent0': None},
# (pid=47832)   60: {'agent0': None},
# (pid=47832)   61: {'agent0': None},
# (pid=47832)   62: {'agent0': None},
# (pid=47832)   63: {'agent0': None}}
# (pid=47832) 2022-07-14 17:35:14,669	INFO sampler.py:823 -- Preprocessed obs: np.ndarray((540,), dtype=float32, min=-1.0, max=14.742, mean=0.169)
# (pid=47832) 2022-07-14 17:35:14,669	INFO sampler.py:827 -- Filtered obs: np.ndarray((540,), dtype=float32, min=-1.0, max=14.742, mean=0.169)
# (pid=47832) 2022-07-14 17:35:14,693	INFO sampler.py:1017 -- Inputs to compute_actions():
# (pid=47832)
# (pid=47832) { 'default_policy': [ { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 0,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=14.742, mean=0.169),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 1,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=6.099, mean=-0.113),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 2,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=10.2, mean=0.172),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 3,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=14.113, mean=0.113),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 4,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=15.212, mean=0.24),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 5,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=13.614, mean=0.056),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 6,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=13.649, mean=0.061),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 7,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=16.506, mean=0.265),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 8,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=14.946, mean=0.135),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 9,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=12.712, mean=0.06),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 10,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=10.496, mean=0.135),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 11,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=14.514, mean=0.191),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 12,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=17.503, mean=0.275),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 13,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=17.247, mean=0.185),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 14,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=16.555, mean=0.08),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 15,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=16.864, mean=0.08),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 16,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=6.092, mean=-0.169),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 17,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=17.553, mean=0.532),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 18,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=15.832, mean=-0.032),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 19,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=30.285, mean=-0.145),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 20,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=12.957, mean=0.031),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 21,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=26.091, mean=-0.113),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 22,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=14.433, mean=0.023),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 23,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=11.563, mean=-0.182),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 24,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=15.642, mean=0.033),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 25,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=10.864, mean=-0.129),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 26,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=11.947, mean=0.163),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 27,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=13.466, mean=0.138),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 28,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=16.986, mean=-0.239),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 29,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=10.284, mean=0.103),
# (pid=47832)                                   'prev_action': None,
# ...
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 49,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=17.276, mean=0.177),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 50,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=10.08, mean=-0.234),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 51,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=14.076, mean=0.2),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 52,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=12.056, mean=-0.167),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 53,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=11.149, mean=0.009),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 54,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=16.62, mean=0.34),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 55,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=9.953, mean=-0.109),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 56,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=20.508, mean=0.123),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 57,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=15.243, mean=0.091),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 58,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=14.563, mean=0.174),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 59,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=10.52, mean=0.127),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 60,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=9.542, mean=0.129),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 61,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=12.736, mean=-0.176),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 62,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=17.577, mean=0.25),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'},
# (pid=47832)                       { 'data': { 'agent_id': 'agent0',
# (pid=47832)                                   'env_id': 63,
# (pid=47832)                                   'info': None,
# (pid=47832)                                   'obs': np.ndarray((540,), dtype=float32, min=-1.0, max=13.834, mean=0.312),
# (pid=47832)                                   'prev_action': None,
# (pid=47832)                                   'prev_reward': None,
# (pid=47832)                                   'rnn_state': None},
# (pid=47832)                         'type': 'PolicyEvalData'}]}
# (pid=47832)
# (pid=47832) 2022-07-14 17:35:14,751	INFO sampler.py:1043 -- Outputs of compute_actions():
# (pid=47832)
# (pid=47832) { 'default_policy': ( np.ndarray((64,), dtype=int64, min=8.0, max=273.0, mean=150.266),
# (pid=47832)                       [],
# (pid=47832)                       { 'action_dist_inputs': np.ndarray((64, 284), dtype=float32, min=-0.023, max=0.025, mean=0.0),
# (pid=47832)                         'action_logp': np.ndarray((64,), dtype=float32, min=-5.658, max=-5.633, mean=-5.648),
# (pid=47832)                         'action_prob': np.ndarray((64,), dtype=float32, min=0.003, max=0.004, mean=0.004),
# (pid=47832)                         'vf_preds': np.ndarray((64,), dtype=float32, min=-0.012, max=0.007, mean=-0.001)})}
# (pid=47832)
# (pid=47832) 2022-07-14 17:35:17,243	INFO simple_list_collector.py:661 -- Trajectory fragment after postprocess_trajectory():
# (pid=47832)
# (pid=47832) { 'agent0': { 'action_dist_inputs': np.ndarray((9, 284), dtype=float32, min=-0.017, max=0.021, mean=0.0),
# (pid=47832)               'action_logp': np.ndarray((9,), dtype=float32, min=-5.656, max=-5.641, mean=-5.648),
# (pid=47832)               'actions': np.ndarray((9,), dtype=int64, min=51.0, max=263.0, mean=165.667),
# (pid=47832)               'advantages': np.ndarray((9,), dtype=float32, min=-0.002, max=0.006, mean=0.001),
# (pid=47832)               'agent_index': np.ndarray((9,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=47832)               'dones': np.ndarray((9,), dtype=bool, min=0.0, max=1.0, mean=0.111),
# (pid=47832)               'eps_id': np.ndarray((9,), dtype=int64, min=219111070.0, max=219111070.0, mean=219111070.0),
# (pid=47832)               'infos': np.ndarray((9,), dtype=object, head={}),
# (pid=47832)               'new_obs': np.ndarray((9, 540), dtype=float32, min=-1.0, max=29.173, mean=0.693),
# (pid=47832)               'obs': np.ndarray((9, 540), dtype=float32, min=-1.0, max=29.173, mean=0.653),
# (pid=47832)               'rewards': np.ndarray((9,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=47832)               'unroll_id': np.ndarray((9,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=47832)               'value_targets': np.ndarray((9,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=47832)               'vf_preds': np.ndarray((9,), dtype=float32, min=-0.006, max=0.002, mean=-0.001)}}
# (pid=47832)
# (pid=47832) 2022-07-14 17:35:17,523	INFO rollout_worker.py:775 -- Completed sample batch:
# (pid=47832)
# (pid=47832) { 'action_dist_inputs': np.ndarray((9, 284), dtype=float32, min=-0.017, max=0.021, mean=0.0),
# (pid=47832)   'action_logp': np.ndarray((9,), dtype=float32, min=-5.656, max=-5.641, mean=-5.648),
# (pid=47832)   'actions': np.ndarray((9,), dtype=int64, min=51.0, max=263.0, mean=165.667),
# (pid=47832)   'advantages': np.ndarray((9,), dtype=float32, min=-0.002, max=0.006, mean=0.001),
# (pid=47832)   'agent_index': np.ndarray((9,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=47832)   'dones': np.ndarray((9,), dtype=bool, min=0.0, max=1.0, mean=0.111),
# (pid=47832)   'eps_id': np.ndarray((9,), dtype=int64, min=219111070.0, max=219111070.0, mean=219111070.0),
# (pid=47832)   'obs': np.ndarray((9, 540), dtype=float32, min=-1.0, max=29.173, mean=0.653),
# (pid=47832)   'rewards': np.ndarray((9,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=47832)   'unroll_id': np.ndarray((9,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=47832)   'value_targets': np.ndarray((9,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=47832)   'vf_preds': np.ndarray((9,), dtype=float32, min=-0.006, max=0.002, mean=-0.001)}
# (pid=47832)
# 2022-07-14 17:35:17,660	INFO tf_policy.py:712 -- Optimizing variable <tf.Variable 'default_policy/fc_1/kernel:0' shape=(540, 256) dtype=float32>
# 2022-07-14 17:35:17,661	INFO tf_policy.py:712 -- Optimizing variable <tf.Variable 'default_policy/fc_1/bias:0' shape=(256,) dtype=float32>
# 2022-07-14 17:35:17,662	INFO tf_policy.py:712 -- Optimizing variable <tf.Variable 'default_policy/fc_value_1/kernel:0' shape=(540, 256) dtype=float32>
# 2022-07-14 17:35:17,663	INFO tf_policy.py:712 -- Optimizing variable <tf.Variable 'default_policy/fc_value_1/bias:0' shape=(256,) dtype=float32>
# 2022-07-14 17:35:17,663	INFO tf_policy.py:712 -- Optimizing variable <tf.Variable 'default_policy/fc_2/kernel:0' shape=(256, 256) dtype=float32>
# 2022-07-14 17:35:17,664	INFO tf_policy.py:712 -- Optimizing variable <tf.Variable 'default_policy/fc_2/bias:0' shape=(256,) dtype=float32>
# 2022-07-14 17:35:17,665	INFO tf_policy.py:712 -- Optimizing variable <tf.Variable 'default_policy/fc_value_2/kernel:0' shape=(256, 256) dtype=float32>
# 2022-07-14 17:35:17,666	INFO tf_policy.py:712 -- Optimizing variable <tf.Variable 'default_policy/fc_value_2/bias:0' shape=(256,) dtype=float32>
# 2022-07-14 17:35:17,666	INFO tf_policy.py:712 -- Optimizing variable <tf.Variable 'default_policy/fc_out/kernel:0' shape=(256, 284) dtype=float32>
# 2022-07-14 17:35:17,667	INFO tf_policy.py:712 -- Optimizing variable <tf.Variable 'default_policy/fc_out/bias:0' shape=(284,) dtype=float32>
# 2022-07-14 17:35:17,667	INFO tf_policy.py:712 -- Optimizing variable <tf.Variable 'default_policy/value_out/kernel:0' shape=(256, 1) dtype=float32>
# 2022-07-14 17:35:17,668	INFO tf_policy.py:712 -- Optimizing variable <tf.Variable 'default_policy/value_out/bias:0' shape=(1,) dtype=float32>
# 2022-07-14 17:35:17,676	INFO multi_gpu_impl.py:143 -- Training on concatenated sample batches:
#
# { 'inputs': [ np.ndarray((576, 540), dtype=float32, min=-1.0, max=86.79, mean=0.546),
#               np.ndarray((576,), dtype=int64, min=1.0, max=283.0, mean=146.33),
#               np.ndarray((576,), dtype=float32, min=0.0, max=0.0, mean=0.0),
#               np.ndarray((576,), dtype=bool, min=0.0, max=1.0, mean=0.111),
#               np.ndarray((576,), dtype=float32, min=-5.662, max=-5.631, mean=-5.649),
#               np.ndarray((576, 284), dtype=float32, min=-0.024, max=0.027, mean=0.0),
#               np.ndarray((576,), dtype=float32, min=-0.02, max=0.012, mean=-0.0),
#               np.ndarray((576,), dtype=float32, min=-2.416, max=3.866, mean=0.0),
#               np.ndarray((576,), dtype=float32, min=0.0, max=0.0, mean=0.0)],
#   'placeholders': [ <tf.Tensor 'default_policy/obs:0' shape=(?, 540) dtype=float32>,
#                     <tf.Tensor 'default_policy/action:0' shape=(?,) dtype=int64>,
#                     <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
#                     <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=float32>,
#                     <tf.Tensor 'default_policy/action_logp:0' shape=(?,) dtype=float32>,
#                     <tf.Tensor 'default_policy/action_dist_inputs:0' shape=(?, 284) dtype=float32>,
#                     <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>,
#                     <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
#                     <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>],
#   'state_inputs': []}
#
# 2022-07-14 17:35:17,678	INFO multi_gpu_impl.py:188 -- Divided 576 rollout sequences, each of length 1, among 1 devices.
# 2022-07-14 17:35:18,225	INFO trainer.py:931 -- Synchronizing weights to workers.
# 2022-07-14 17:35:18,469	INFO trainer.py:866 -- Evaluating current policy for 8192 episodes.
# 2022-07-14 17:35:18,471	INFO rollout_worker.py:737 -- Generating sample batch of size 9
